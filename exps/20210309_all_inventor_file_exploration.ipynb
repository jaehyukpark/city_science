# %%
import pandas as pd

# %%
raw_df = pd.read_csv("../data/uspto/2019/all_inventors.csv", nrows=10000)
raw_df.head()
# Out:
#    application_number inventor_name_first inventor_name_middle  \
# 0             5692088                TROY                   E.
# 1             5692088               JAMES                   E.
# 2             5692179              PIETRO
# 3             5692179             FRANCIS                   J.
# 4             5692179             CHESTER                   J.
#
#   inventor_name_last  inventor_rank inventor_city_name inventor_region_code  \
# 0              PLUNK              1            Bedford                   MA
# 1             HOPSON              2          Wellesley                   MA
# 2          VENTRESCA              1          Littleton                   MA
# 3             O'HARA              2            Bedford                   MA
# 4               HUNT              3            Melrose                   MA
#
#   inventor_country_code
# 0                    US
# 1                    US
# 2                    US
# 3                    US
# ...

# %%
city2fips_df = pd.read_csv("../data/complementary/us_cities_states_counties_raw.csv", sep="|")
city2fips_df.head()
# Out:
#          City State short   State full    County                City alias
# 0  Holtsville          NY     New York   SUFFOLK  Internal Revenue Service
# 1  Holtsville          NY     New York   SUFFOLK                Holtsville
# 2    Adjuntas          PR  Puerto Rico  ADJUNTAS           URB San Joaquin
# 3    Adjuntas          PR  Puerto Rico  ADJUNTAS          Jard De Adjuntas
# 4    Adjuntas          PR  Puerto Rico  ADJUNTAS       Colinas Del Gigante
