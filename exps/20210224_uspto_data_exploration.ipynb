# %%
import pandas as pd

# %%
corr_df = pd.read_csv("../data/uspto/2019/correspondence_address.csv", nrows=10000)
corr_df.tail()
# Out:
#       application_number correspondence_name correspondence_street_line_1  \
# 9995             5670764                 NaN                          NaN
# 9996             5670722                 NaN                          NaN
# 9997             5670703                 NaN                          NaN
# 9998             5670543                 NaN                          NaN
# 9999             5670557                 NaN                          NaN
#
#      correspondence_street_line_2 correspondence_street_line_3  \
# 9995                          NaN                          NaN
# 9996                          NaN                          NaN
# 9997                          NaN                          NaN
# 9998                          NaN                          NaN
# 9999                          NaN                          NaN
#
#      correspondence_city correspondence_postal_code  \
# 9995                 NaN                        NaN
# ...

# %%
app_df = pd.read_csv("../data/uspto/2019/application_data.csv", nrows=10000)
app_df.head()
# Out:
#    application_number filing_date application_invention_type  \
# 0             2000161         NaN                    Utility
# 1             2022946         NaN                    Utility
# 2             2032617         NaN                    Utility
# 3             2045760  1948-08-23                        NaN
# 4             2048602         NaN                        NaN
#
#   examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0                NaN               NaN        NaN           NaN
# 1                NaN               NaN        NaN           NaN
# 2                NaN               NaN        NaN           NaN
# 3                NaN               NaN        NaN           NaN
# 4                NaN               NaN        NaN           NaN
#
#    confirm_number atty_docket_number  \
# 0            1014                NaN
# 1            1141                NaN
# 2            1195                NaN
# 3            1267                NaN
# ...

# %%
inventor_df = pd.read_csv("../data/uspto/2019/all_inventors.csv", nrows=10000)
inventor_df.head()
# Out:
#    application_number inventor_name_first inventor_name_middle  \
# 0             5692088                TROY                   E.
# 1             5692088               JAMES                   E.
# 2             5692179              PIETRO
# 3             5692179             FRANCIS                   J.
# 4             5692179             CHESTER                   J.
#
#   inventor_name_last  inventor_rank inventor_city_name inventor_region_code  \
# 0              PLUNK              1            Bedford                   MA
# 1             HOPSON              2          Wellesley                   MA
# 2          VENTRESCA              1          Littleton                   MA
# 3             O'HARA              2            Bedford                   MA
# 4               HUNT              3            Melrose                   MA
#
#   inventor_country_code
# 0                    US
# 1                    US
# 2                    US
# 3                    US
# ...
